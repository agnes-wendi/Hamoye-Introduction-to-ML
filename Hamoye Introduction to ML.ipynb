# %%
import pandas as pd
df=pd.read_csv("https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding="latin-1")
df.groupby("Element").sum()# sum of Processing in 2017
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
df.groupby("Item").sum()# sum of Wine produced in 2015 and 2018
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %%
df.groupby("Area").max()# area with highest sum in 2017
# Out:
#                              Area Code  Item Code          Item  Element Code  \
# Area
# Algeria                              4       2961          Yams          5911
# Angola                               7       2961          Yams          5911
# Benin                               53       2961          Yams          5911
# Botswana                            20       2961          Yams          5911
# Burkina Faso                       233       2961          Yams          5911
# Cabo Verde                          35       2961          Yams          5911
# Cameroon                            32       2961          Yams          5911
# Central African Republic            37       2961          Yams          5911
# Chad                                39       2961          Yams          5911
# Comoros                             45       2782  Pelagic Fish          5911
# Congo                               46       2961          Yams          5911
# ...

# %%
df.groupby("Area").min()# 7th lowest sum in 2017
# Out:
#                              Area Code  Item Code                     Item  \
# Area
# Algeria                              4       2501        Alcohol, Non-Food
# Angola                               7       2501        Alcohol, Non-Food
# Benin                               53       2501        Alcohol, Non-Food
# Botswana                            20       2501        Alcohol, Non-Food
# Burkina Faso                       233       2501        Alcohol, Non-Food
# Cabo Verde                          35       2501        Alcohol, Non-Food
# Cameroon                            32       2501        Alcohol, Non-Food
# Central African Republic            37       2501        Alcohol, Non-Food
# Chad                                39       2501        Alcohol, Non-Food
# Comoros                             45       2761              Cephalopods
# Congo                               46       2501        Alcohol, Non-Food
# ...

# %%
df.corr()# correlation with Element code
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
df.groupby("Element").max()# highest stock variation
# Out:
#                                         Area Code                   Area  \
# Element
# Domestic supply quantity                      276               Zimbabwe
# Export Quantity                               276               Zimbabwe
# Fat supply quantity (g/capita/day)            276               Zimbabwe
# Feed                                          276               Zimbabwe
# Food                                          276               Zimbabwe
# Food supply (kcal/capita/day)                 276               Zimbabwe
# Food supply quantity (kg/capita/yr)           276               Zimbabwe
# Import Quantity                               276               Zimbabwe
# Losses                                        276               Zimbabwe
# Other uses (non-food)                         276               Zimbabwe
# Processing                                    276               Zimbabwe
# Production                                    276               Zimbabwe
# ...

# %%
df["Area"].nunique()# total number of unique countries in the dataset
# Out:
# 49

# %%
df["Y2017"].mean()# 2017 mean
# Out:
# 140.917764860268

# %%
df["Y2017"].std()# 2017 standard deviation
# Out:
# 1671.8623590572788

# %%
df["Y2014"].isnull().sum()# total number of missing data in 2014
# Out:
# 1589
